# %% [markdown]
# <a href="https://colab.research.google.com/github/Yewon9/Emotion_Recognition/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMPORT

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from statistics import mode, StatisticsError
import os
from tqdm import tqdm
import librosa
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # DATA

# %% [markdown]
# ## aihub_4

# %%
aihub_4 = pd.read_csv('/content/drive/MyDrive/project/data_aihub/4.csv', encoding = 'CP949')
aihub_4.head()
# Out:
#                      wav_id                        발화문     상황    1번 감정  \
# 0  5e258fd1305bcf3ad153a6a4           어, 청소 니가 대신 해 줘!  anger  Neutral
# 1  5e258fe2305bcf3ad153a6a5         둘 다 청소 하기 싫어. 귀찮아.  anger  Neutral
# 2  5e258ff5305bcf3ad153a6a6             둘 다 하기 싫어서 화내.  anger    Angry
# 3  5e25902f305bcf3ad153a6a9                그럼 방세는 어떡해.  anger  Sadness
# 4  5e27f90b5807b852d9e0157b  권태긴줄 알았는데 다른 사람이 생겼나보더라고.    sad  Sadness
#
#    1번 감정세기    2번 감정  2번 감정세기    3번 감정  3번 감정세기    4번 감정  4번감정세기    5번 감정  \
# 0        0    Angry        1  Neutral        0  Neutral       0    Angry
# 1        0    Angry        1  Neutral        0  Neutral       0    Angry
# 2        1    Angry        1  Neutral        0    Angry       1    Angry
# 3        1  Sadness        1  Sadness        1  Sadness       1  Sadness
# 4        1  Sadness        1  Sadness        1  Sadness       2  Sadness
#
#    5번 감정세기  나이    성별
# 0        1  27  male
# 1        1  27  male
# 2        1  27  male
# 3        1  27  male
# 4        1  32  male

# %%
aihub_4.shape
# Out:
# (14606, 15)

# %%
def determine_majority(row):
  try:
    return mode(row[['1번 감정', '2번 감정', '3번 감정', '4번 감정', '5번 감정']].tolist())
  except StatisticsError:
    return None

# %%
aihub_4['Emotion'] = aihub_4.apply(determine_majority, axis = 1)

# %%
aihub_4 = aihub_4.dropna(subset = ['Emotion'])
print(aihub_4)
# Out:
#                          wav_id  \
# 0      5e258fd1305bcf3ad153a6a4
# 1      5e258fe2305bcf3ad153a6a5
# 2      5e258ff5305bcf3ad153a6a6
# 3      5e25902f305bcf3ad153a6a9
# 4      5e27f90b5807b852d9e0157b
# ...                         ...
# 14601  5e53d6067bef803b4851dfc6
# 14602  5e53d61cc38c123b9ec6dde6
# 14603  5e53d6332a2d173b73a03210
# 14604  5e53d659963e443aee02b7d0
# 14605  5e53d6778849ac3aacea576f
#
#                                                      발화문     상황    1번 감정  \
# 0                                       어, 청소 니가 대신 해 줘!  anger  Neutral
# 1                                     둘 다 청소 하기 싫어. 귀찮아.  anger  Neutral
# 2                                         둘 다 하기 싫어서 화내.  anger    Angry
# 3                                            그럼 방세는 어떡해.  anger  Sadness
# 4                              권태긴줄 알았는데 다른 사람이 생겼나보더라고.    sad  Sadness
# ...                                                  ...    ...      ...
# 14601                             아, 요즘 룸메랑 너무 자주 싸우게 돼.  anger  Disgust
# 14602                  아, 룸메가 방을 너무 지저분하게 써. 음식물도 막 버리고.  anger  Disgust
# 14603  뭐 화를 낸 것까진 아니지만, 한 달 전 쯤에 좀 확실하게 얘기를 해뒀거든. 근데 ...  anger  Disgust
# 14604            어. 고등학교 동창인데, 같은 동네 오게 돼서 같이 룸메로 살게 됐지.  anger  Neutral
# 14605                                      그게 확실한 방법이겠지?  anger  Neutral
#
#        1번 감정세기    2번 감정  2번 감정세기    3번 감정  3번 감정세기    4번 감정  4번감정세기    5번 감정  \
# 0            0    Angry        1  Neutral        0  Neutral       0    Angry
# 1            0    Angry        1  Neutral        0  Neutral       0    Angry
# 2            1    Angry        1  Neutral        0    Angry       1    Angry
# 3            1  Sadness        1  Sadness        1  Sadness       1  Sadness
# 4            1  Sadness        1  Sadness        1  Sadness       2  Sadness
# ...        ...      ...      ...      ...      ...      ...     ...      ...
# 14601        1    Angry        2    Angry        1  Disgust       1    Angry
# 14602        1    Angry        2    Angry        1  Disgust       1    Angry
# 14603        1    Angry        2  Sadness        1  Disgust       1    Angry
# 14604        0    Angry        1  Sadness        1  Neutral       0  Neutral
# 14605        0    Angry        1  Sadness        1  Disgust       1  Neutral
#
#        5번 감정세기  나이    성별  Emotion
# 0            1  27  male  Neutral
# 1            1  27  male  Neutral
# 2            1  27  male    Angry
# 3            1  27  male  Sadness
# 4            1  32  male  Sadness
# ...        ...  ..   ...      ...
# 14601        1  35  male    Angry
# 14602        1  35  male    Angry
# 14603        2  35  male  Disgust
# 14604        0  35  male  Neutral
# 14605        0  35  male  Neutral
#
# [14606 rows x 16 columns]

# %%
front = aihub_4.iloc[:, :2]
back = aihub_4.iloc[:, -1:]

# %%
aihub_4 = pd.concat([front, back], axis = 1)
aihub_4.head()
# Out:
#                      wav_id                        발화문  Emotion
# 0  5e258fd1305bcf3ad153a6a4           어, 청소 니가 대신 해 줘!  Neutral
# 1  5e258fe2305bcf3ad153a6a5         둘 다 청소 하기 싫어. 귀찮아.  Neutral
# 2  5e258ff5305bcf3ad153a6a6             둘 다 하기 싫어서 화내.    Angry
# 3  5e25902f305bcf3ad153a6a9                그럼 방세는 어떡해.  Sadness
# 4  5e27f90b5807b852d9e0157b  권태긴줄 알았는데 다른 사람이 생겼나보더라고.  Sadness

# %%
aihub_4['Path'] = '/content/drive/MyDrive/project/data_aihub/4/' + aihub_4['wav_id'] + '.wav'
aihub_4.head()
# Out:
#                      wav_id                        발화문  Emotion  \
# 0  5e258fd1305bcf3ad153a6a4           어, 청소 니가 대신 해 줘!  Neutral
# 1  5e258fe2305bcf3ad153a6a5         둘 다 청소 하기 싫어. 귀찮아.  Neutral
# 2  5e258ff5305bcf3ad153a6a6             둘 다 하기 싫어서 화내.    Angry
# 3  5e25902f305bcf3ad153a6a9                그럼 방세는 어떡해.  Sadness
# 4  5e27f90b5807b852d9e0157b  권태긴줄 알았는데 다른 사람이 생겼나보더라고.  Sadness
#
#                                                 Path
# 0  /content/drive/MyDrive/project/data_aihub/4/5e...
# 1  /content/drive/MyDrive/project/data_aihub/4/5e...
# 2  /content/drive/MyDrive/project/data_aihub/4/5e...
# 3  /content/drive/MyDrive/project/data_aihub/4/5e...
# 4  /content/drive/MyDrive/project/data_aihub/4/5e...

# %% [markdown]
# ## aihub_5

# %%
aihub_5 = pd.read_csv('/content/drive/MyDrive/project/data_aihub/5.csv', encoding = 'CP949')
aihub_5.head()
# Out:
#                      wav_id                                          발화문  \
# 0  5ed10dbc2880d70f286121c3    개를 예쁘다고 사놓고 끝까지 키우지도 않고 버리는 사람들이 엄청 많아졌대.
# 1  5ecb60ef9aa8ea0eec53edb1                      지금도 그대로 있어. 치우는 사람이 없어.
# 2  5f052858b140144dfcfef768                맞아. 무기력증인 것 같아. 한동안 정말 바빴었거든.
# 3  5f0e72c4b140144dfcff3fa5  오늘이 발표날인데 연락이 없더라고. 그래서 알아봤더니 명단에 내 이름이 없대.
# 4  5ed10ddd7e21a10eee2537ce     그치. 개 키우는 사람이 늘어나니까 그만큼 버리는 사람도 늘어나는 거야!
#
#         상황    1번 감정  1번 감정세기    2번 감정  2번 감정세기    3번 감정  3번 감정세기    4번 감정  \
# 0  disgust    Angry        2    Angry        2    Angry        2    Angry
# 1  disgust  Neutral        0  Disgust        2  Sadness        2  Disgust
# 2      sad  Sadness        2  Sadness        1  Sadness        2  Sadness
# 3      sad  Sadness        1  Sadness        2  Sadness        2  Sadness
# 4  disgust    Angry        2    Angry        2    Angry        2    Angry
#
#    4번감정세기    5번 감정  5번 감정세기  나이      성별
# 0       2    Angry        2  33  female
# 1       2  Disgust        1  48  female
# 2       2  Sadness        2  48  female
# 3       2  Sadness        2  48  female
# 4       2  Sadness        2  33  female

# %%
aihub_5.shape
# Out:
# (10011, 15)

# %%
aihub_5['Emotion'] = aihub_5.apply(determine_majority, axis = 1)

# %%
aihub_5 = aihub_5.dropna(subset = ['Emotion'])
print(aihub_5)
# Out:
#                          wav_id  \
# 0      5ed10dbc2880d70f286121c3
# 1      5ecb60ef9aa8ea0eec53edb1
# 2      5f052858b140144dfcfef768
# 3      5f0e72c4b140144dfcff3fa5
# 4      5ed10ddd7e21a10eee2537ce
# ...                         ...
# 10006  5f05ffd5b140144dfcff01c7
# 10007  5ec53bf82880d70f28611de0
# 10008  5f0b2b5ab140144dfcff2759
# 10009  5f0b2b75b140144dfcff275a
# 10010  5f0527b3b140144dfcfef75e
#
#                                                      발화문       상황    1번 감정  \
# 0              개를 예쁘다고 사놓고 끝까지 키우지도 않고 버리는 사람들이 엄청 많아졌대.  disgust    Angry
# 1                                지금도 그대로 있어. 치우는 사람이 없어.  disgust  Neutral
# 2                          맞아. 무기력증인 것 같아. 한동안 정말 바빴었거든.      sad  Sadness
# 3            오늘이 발표날인데 연락이 없더라고. 그래서 알아봤더니 명단에 내 이름이 없대.      sad  Sadness
# 4               그치. 개 키우는 사람이 늘어나니까 그만큼 버리는 사람도 늘어나는 거야!  disgust    Angry
# ...                                                  ...      ...      ...
# 10006  너의 말 대로 약속 장소를 옮겨 보는 것도 좋은 방법 같아. 나는 취소할 생각만 했...     fear  Neutral
# 10007                     산책하는 게 나을 것 같아. 이제부터 산책 좀 해볼게.      sad  Neutral
# 10008                너의 말을 듣고보니까 약속장소를 옮겨보는 것도 좋은 방법 같아.     fear  Neutral
# 10009  오늘 친구한테 전화해서 안좋은 상황이니까 약속을 미룰지 약속 장소를 변경할지 상의해...     fear  Neutral
# 10010        사람이 많이 다니는 강남역보다는 공원이 훨씬 더 낫겠지. 내가 한번 바꿔볼게!     fear  Neutral
#
#        1번 감정세기      2번 감정  2번 감정세기      3번 감정  3번 감정세기    4번 감정  4번감정세기  \
# 0            2      Angry        2      Angry        2    Angry       2
# 1            0    Disgust        2    Sadness        2  Disgust       2
# 2            2    Sadness        1    Sadness        2  Sadness       2
# 3            1    Sadness        2    Sadness        2  Sadness       2
# 4            2      Angry        2      Angry        2    Angry       2
# ...        ...        ...      ...        ...      ...      ...     ...
# 10006        0  Happiness        1    Sadness        1  Neutral       0
# 10007        0  Happiness        1  Happiness        1  Neutral       0
# 10008        0  Happiness        1    Sadness        1  Neutral       0
# 10009        0       Fear        1    Sadness        1  Neutral       0
# 10010        0       Fear        1  Happiness        1  Neutral       0
#
#          5번 감정  5번 감정세기  나이      성별  Emotion
# 0        Angry        2  33  female    Angry
# 1      Disgust        1  48  female  Disgust
# 2      Sadness        2  48  female  Sadness
# 3      Sadness        2  48  female  Sadness
# 4      Sadness        2  33  female    Angry
# ...        ...      ...  ..     ...      ...
# 10006  Neutral        0  46  female  Neutral
# 10007  Sadness        1  48  female  Neutral
# 10008  Neutral        0  46  female  Neutral
# 10009     Fear        1  46  female  Neutral
# 10010     Fear        2  48  female  Neutral
#
# [10011 rows x 16 columns]

# %%
front = aihub_5.iloc[:, :2]
back = aihub_5.iloc[:, -1:]

# %%
aihub_5 = pd.concat([front, back], axis = 1)
aihub_5.head()
# Out:
#                      wav_id                                          발화문  \
# 0  5ed10dbc2880d70f286121c3    개를 예쁘다고 사놓고 끝까지 키우지도 않고 버리는 사람들이 엄청 많아졌대.
# 1  5ecb60ef9aa8ea0eec53edb1                      지금도 그대로 있어. 치우는 사람이 없어.
# 2  5f052858b140144dfcfef768                맞아. 무기력증인 것 같아. 한동안 정말 바빴었거든.
# 3  5f0e72c4b140144dfcff3fa5  오늘이 발표날인데 연락이 없더라고. 그래서 알아봤더니 명단에 내 이름이 없대.
# 4  5ed10ddd7e21a10eee2537ce     그치. 개 키우는 사람이 늘어나니까 그만큼 버리는 사람도 늘어나는 거야!
#
#    Emotion
# 0    Angry
# 1  Disgust
# 2  Sadness
# 3  Sadness
# 4    Angry

# %%
aihub_5['Path'] = '/content/drive/MyDrive/project/data_aihub/5/' + aihub_5['wav_id'] + '.wav'
aihub_5.head()
# Out:
#                      wav_id                                          발화문  \
# 0  5ed10dbc2880d70f286121c3    개를 예쁘다고 사놓고 끝까지 키우지도 않고 버리는 사람들이 엄청 많아졌대.
# 1  5ecb60ef9aa8ea0eec53edb1                      지금도 그대로 있어. 치우는 사람이 없어.
# 2  5f052858b140144dfcfef768                맞아. 무기력증인 것 같아. 한동안 정말 바빴었거든.
# 3  5f0e72c4b140144dfcff3fa5  오늘이 발표날인데 연락이 없더라고. 그래서 알아봤더니 명단에 내 이름이 없대.
# 4  5ed10ddd7e21a10eee2537ce     그치. 개 키우는 사람이 늘어나니까 그만큼 버리는 사람도 늘어나는 거야!
#
#    Emotion                                               Path
# 0    Angry  /content/drive/MyDrive/project/data_aihub/5/5e...
# 1  Disgust  /content/drive/MyDrive/project/data_aihub/5/5e...
# 2  Sadness  /content/drive/MyDrive/project/data_aihub/5/5f...
# 3  Sadness  /content/drive/MyDrive/project/data_aihub/5/5f...
# 4    Angry  /content/drive/MyDrive/project/data_aihub/5/5e...

# %% [markdown]
# ## aihub_5_2

# %%
aihub_5_2 = pd.read_csv('/content/drive/MyDrive/project/data_aihub/5_2.csv', encoding = 'CP949')
aihub_5_2.head()
# Out:
#                      wav_id  \
# 0  5f4141e29dd513131eacee2f
# 1  5f4141f59dd513131eacee30
# 2  5f4142119dd513131eacee31
# 3  5f4142279dd513131eacee32
# 4  5f3c9ed98a3c1005aa97c4bd
#
#                                                  발화문         상황      1번 감정  \
# 0                                   헐! 나 이벤트에 당첨 됐어.  happiness      angry
# 1        내가 좋아하는 인플루언서가 이벤트를 하더라고. 그래서 그냥 신청 한번 해봤지.  happiness    neutral
# 2                        한 명 뽑는 거였는데, 그게 바로 내가 된 거야.  happiness      angry
# 3  당연히 마음에 드는 선물이니깐, 이벤트에 내가 신청 한번 해본 거지. 비싼 거야. ...  happiness      angry
# 4                   에피타이저 정말 좋아해. 그 것도 괜찮은 생각인 것 같애.    neutral  happiness
#
#    1번 감정세기      2번 감정  2번 감정세기      3번 감정  3번 감정세기      4번 감정  4번감정세기  \
# 0        2   surprise        2  happiness        2  happiness       2
# 1        0  happiness        2  happiness        2  happiness       2
# 2        2  happiness        2  happiness        2  happiness       2
# 3        2  happiness        2  happiness        2  happiness       2
# 4        2  happiness        1  happiness        2  happiness       1
#
#        5번 감정  5번 감정세기  나이      성별
# 0  happiness        2  48  female
# 1  happiness        2  48  female
# 2  happiness        2  48  female
# 3  happiness        1  48  female
# 4  happiness        1  48  female

# %%
aihub_5_2.shape
# Out:
# (19374, 15)

# %%
aihub_5_2['Emotion'] = aihub_5_2.apply(determine_majority, axis = 1)

# %%
aihub_5_2 = aihub_5_2.dropna(subset = ['Emotion'])
print(aihub_5_2)
# Out:
#                          wav_id  \
# 0      5f4141e29dd513131eacee2f
# 1      5f4141f59dd513131eacee30
# 2      5f4142119dd513131eacee31
# 3      5f4142279dd513131eacee32
# 4      5f3c9ed98a3c1005aa97c4bd
# ...                         ...
# 19369  5fbe313c44697678c497c05a
# 19370  5fbe251044697678c497bfb8
# 19371  5fbe31584c55eb78bd7cee7f
# 19372  5fbe2f8544697678c497c047
# 19373  5fbe36714c55eb78bd7ceea3
#
#                                                      발화문         상황  \
# 0                                       헐! 나 이벤트에 당첨 됐어.  happiness
# 1            내가 좋아하는 인플루언서가 이벤트를 하더라고. 그래서 그냥 신청 한번 해봤지.  happiness
# 2                            한 명 뽑는 거였는데, 그게 바로 내가 된 거야.  happiness
# 3      당연히 마음에 드는 선물이니깐, 이벤트에 내가 신청 한번 해본 거지. 비싼 거야. ...  happiness
# 4                       에피타이저 정말 좋아해. 그 것도 괜찮은 생각인 것 같애.    neutral
# ...                                                  ...        ...
# 19369                                      나 엘리베이터에 갇혔어.       fear
# 19370                                  하지만 기분이 나쁜 걸 어떡해?      angry
# 19371                                  자취방 엘리베이턴데 정전인가봐.       fear
# 19372                                    나 드디어 프로젝트 끝났어!  happiness
# 19373                                         걱정해줘서 고마워.    disgust
#
#            1번 감정  1번 감정세기      2번 감정  2번 감정세기      3번 감정  3번 감정세기      4번 감정  \
# 0          angry        2   surprise        2  happiness        2  happiness
# 1        neutral        0  happiness        2  happiness        2  happiness
# 2          angry        2  happiness        2  happiness        2  happiness
# 3          angry        2  happiness        2  happiness        2  happiness
# 4      happiness        2  happiness        1  happiness        2  happiness
# ...          ...      ...        ...      ...        ...      ...        ...
# 19369  happiness        1    sadness        1    sadness        2    sadness
# 19370    sadness        1       fear        1    sadness        2    sadness
# 19371    sadness        1    neutral        0    sadness        2       fear
# 19372    disgust        1    sadness        1    neutral        0  happiness
# 19373    neutral        0    neutral        0    neutral        0    neutral
#
#        4번감정세기      5번 감정  5번 감정세기  나이      성별    Emotion
# 0           2  happiness        2  48  female  happiness
# 1           2  happiness        2  48  female  happiness
# 2           2  happiness        2  48  female  happiness
# 3           2  happiness        1  48  female  happiness
# 4           1  happiness        1  48  female  happiness
# ...       ...        ...      ...  ..     ...        ...
# 19369       1    sadness        1  23  female    sadness
# 19370       1    neutral        0  23  female    sadness
# 19371       1    sadness        1  23  female    sadness
# 19372       1    sadness        1  23  female    sadness
# 19373       0    neutral        0  23  female    neutral
#
# [19374 rows x 16 columns]

# %%
front = aihub_5_2.iloc[:, :2]
back = aihub_5_2.iloc[:, -1:]

# %%
aihub_5_2 = pd.concat([front, back], axis = 1)
aihub_5_2.head()
# Out:
#                      wav_id  \
# 0  5f4141e29dd513131eacee2f
# 1  5f4141f59dd513131eacee30
# 2  5f4142119dd513131eacee31
# 3  5f4142279dd513131eacee32
# 4  5f3c9ed98a3c1005aa97c4bd
#
#                                                  발화문    Emotion
# 0                                   헐! 나 이벤트에 당첨 됐어.  happiness
# 1        내가 좋아하는 인플루언서가 이벤트를 하더라고. 그래서 그냥 신청 한번 해봤지.  happiness
# 2                        한 명 뽑는 거였는데, 그게 바로 내가 된 거야.  happiness
# 3  당연히 마음에 드는 선물이니깐, 이벤트에 내가 신청 한번 해본 거지. 비싼 거야. ...  happiness
# 4                   에피타이저 정말 좋아해. 그 것도 괜찮은 생각인 것 같애.  happiness

# %%
aihub_5_2['Path'] = '/content/drive/MyDrive/project/data_aihub/5_2/' + aihub_5_2['wav_id'] + '.wav'
aihub_5_2.head()
# Out:
#                      wav_id  \
# 0  5f4141e29dd513131eacee2f
# 1  5f4141f59dd513131eacee30
# 2  5f4142119dd513131eacee31
# 3  5f4142279dd513131eacee32
# 4  5f3c9ed98a3c1005aa97c4bd
#
#                                                  발화문    Emotion  \
# 0                                   헐! 나 이벤트에 당첨 됐어.  happiness
# 1        내가 좋아하는 인플루언서가 이벤트를 하더라고. 그래서 그냥 신청 한번 해봤지.  happiness
# 2                        한 명 뽑는 거였는데, 그게 바로 내가 된 거야.  happiness
# 3  당연히 마음에 드는 선물이니깐, 이벤트에 내가 신청 한번 해본 거지. 비싼 거야. ...  happiness
# 4                   에피타이저 정말 좋아해. 그 것도 괜찮은 생각인 것 같애.  happiness
#
#                                                 Path
# 0  /content/drive/MyDrive/project/data_aihub/5_2/...
# 1  /content/drive/MyDrive/project/data_aihub/5_2/...
# 2  /content/drive/MyDrive/project/data_aihub/5_2/...
# 3  /content/drive/MyDrive/project/data_aihub/5_2/...
# 4  /content/drive/MyDrive/project/data_aihub/5_2/...

# %% [markdown]
# ## aihub

# %%
aihub = pd.concat([aihub_4, aihub_5, aihub_5_2], axis = 0)
aihub
# Out:
#                          wav_id                        발화문  Emotion  \
# 0      5e258fd1305bcf3ad153a6a4           어, 청소 니가 대신 해 줘!  Neutral
# 1      5e258fe2305bcf3ad153a6a5         둘 다 청소 하기 싫어. 귀찮아.  Neutral
# 2      5e258ff5305bcf3ad153a6a6             둘 다 하기 싫어서 화내.    Angry
# 3      5e25902f305bcf3ad153a6a9                그럼 방세는 어떡해.  Sadness
# 4      5e27f90b5807b852d9e0157b  권태긴줄 알았는데 다른 사람이 생겼나보더라고.  Sadness
# ...                         ...                        ...      ...
# 19369  5fbe313c44697678c497c05a              나 엘리베이터에 갇혔어.  sadness
# 19370  5fbe251044697678c497bfb8          하지만 기분이 나쁜 걸 어떡해?  sadness
# 19371  5fbe31584c55eb78bd7cee7f          자취방 엘리베이턴데 정전인가봐.  sadness
# 19372  5fbe2f8544697678c497c047            나 드디어 프로젝트 끝났어!  sadness
# 19373  5fbe36714c55eb78bd7ceea3                 걱정해줘서 고마워.  neutral
#
#                                                     Path
# 0      /content/drive/MyDrive/project/data_aihub/4/5e...
# 1      /content/drive/MyDrive/project/data_aihub/4/5e...
# 2      /content/drive/MyDrive/project/data_aihub/4/5e...
# 3      /content/drive/MyDrive/project/data_aihub/4/5e...
# 4      /content/drive/MyDrive/project/data_aihub/4/5e...
# ...                                                  ...
# 19369  /content/drive/MyDrive/project/data_aihub/5_2/...
# 19370  /content/drive/MyDrive/project/data_aihub/5_2/...
# 19371  /content/drive/MyDrive/project/data_aihub/5_2/...
# 19372  /content/drive/MyDrive/project/data_aihub/5_2/...
# 19373  /content/drive/MyDrive/project/data_aihub/5_2/...
#
# [43991 rows x 4 columns]

# %%
aihub = aihub.drop_duplicates(subset = '발화문')
aihub.shape
# Out:
# (37212, 4)

# %%
emotion_counts = aihub['Emotion'].value_counts()
emotion_counts
# Out:
# Emotion
# Sadness      11088
# Angry         5410
# neutral       5233
# sadness       3021
# happiness     2981
# Neutral       1780
# angry         1700
# Fear          1396
# disgust       1320
# Disgust       1131
# fear           929
# surprise       873
# Happiness      269
# Surprise        81
# Name: count, dtype: int64

# %%
aihub['Emotion'] = aihub['Emotion'].str.lower()
# Out:
# <ipython-input-30-825f5e21d148>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aihub['Emotion'] = aihub['Emotion'].str.lower()

# %%
emotion_counts = aihub['Emotion'].value_counts()
emotion_counts
# Out:
# Emotion
# sadness      14109
# angry         7110
# neutral       7013
# happiness     3250
# disgust       2451
# fear          2325
# surprise       954
# Name: count, dtype: int64

# %%
aihub.shape
# Out:
# (37212, 4)

# %%
aihub = aihub[aihub['Path'].apply(lambda x: os.path.exists(x))]
aihub.shape
# Out:
# (37196, 4)

# %%
aihub = aihub.iloc[:, [2, 3]]
aihub = aihub.rename(columns = {'감정' : 'Emotions', 'Path' : 'Path'})
aihub
# Out:
#        Emotion                                               Path
# 0      neutral  /content/drive/MyDrive/project/data_aihub/4/5e...
# 1      neutral  /content/drive/MyDrive/project/data_aihub/4/5e...
# 2        angry  /content/drive/MyDrive/project/data_aihub/4/5e...
# 3      sadness  /content/drive/MyDrive/project/data_aihub/4/5e...
# 4      sadness  /content/drive/MyDrive/project/data_aihub/4/5e...
# ...        ...                                                ...
# 19366  neutral  /content/drive/MyDrive/project/data_aihub/5_2/...
# 19367  neutral  /content/drive/MyDrive/project/data_aihub/5_2/...
# 19368  sadness  /content/drive/MyDrive/project/data_aihub/5_2/...
# 19370  sadness  /content/drive/MyDrive/project/data_aihub/5_2/...
# 19371  sadness  /content/drive/MyDrive/project/data_aihub/5_2/...
#
# [37196 rows x 2 columns]

# %%
aihub.to_csv('aihub.csv', index = False, encoding = 'utf-8-sig')

# %% [markdown]
# # EDA

# %%
data = pd.read_csv('aihub.csv')
data.shape
# Out:
# (37196, 2)

# %%
emotion_counts = data['Emotion'].value_counts()
emotion_counts
# Out:
# Emotion
# sadness      14098
# angry         7108
# neutral       7010
# happiness     3250
# disgust       2451
# fear          2325
# surprise       954
# Name: count, dtype: int64

# %%
data = data[data['Emotion'] != 'surprise']
data.shape
# Out:
# (36242, 2)

# %%
emotions_to_downsample = ['sadness', 'angry', 'neutral', 'happiness']

# %%
dfs = []
for emotion in emotions_to_downsample:
    emotion_data = data[data['Emotion'] == emotion]
    if len(emotion_data) > 2500:
        downsampled_data = emotion_data.sample(n = 2500, random_state = 42)
    else:
        downsampled_data = emotion_data
    dfs.append(downsampled_data)

# %%
disgust_data = data[data['Emotion'] == 'disgust']
fear_data = data[data['Emotion'] == 'fear']
dfs.append(disgust_data)
dfs.append(fear_data)

# %%
final_df = pd.concat(dfs)
final_df.shape
# Out:
# (14776, 2)

# %%
print(final_df['Emotion'].value_counts())
# Out:
# Emotion
# sadness      2500
# angry        2500
# neutral      2500
# happiness    2500
# disgust      2451
# fear         2325
# Name: count, dtype: int64

# %%
final_df.to_csv('balanced_emotion_data.csv', index = False)

# %%
balanced_data = pd.read_csv('balanced_emotion_data.csv')

# %%
tqdm.pandas()

def get_audio_length(file_path):
  try:
    y, sr = librosa.load(file_path, sr = None)
    return librosa.get_duration(y = y, sr= sr)
  except:
    return None

# %%
balanced_data['Length'] = balanced_data['Path'].progress_apply(get_audio_length)

# %%
plt.figure(figsize = (10, 6))
sns.histplot(balanced_data['Length'], bins = 50, kde = True)
plt.title('Wav Length')
plt.xlabel('second')
plt.ylabel('count')
plt.show()

# %%
# 시각화 결과 gpt에 넣어서 어느 정도 삭제하는게 맞는지 찾기
